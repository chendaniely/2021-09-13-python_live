# %%
import pandas

# %%
pandas.__version__
# Out:
# '1.3.3'

# %%
pandas.read_csv("../data/gapminder.tsv", sep="\t")
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
# using an alias
import pandas as pd
# don't do
# from pandas import *

# %%
pd.read_csv("../data/gapminder.tsv", sep="\t")
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
dat = pd.read_csv("../data/gapminder.tsv", sep="\t")

# %%
dat
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
type(dat)
# Out:
# pandas.core.frame.DataFrame

# %%
dat.shape
# Out:
# (1704, 6)

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
pwd
# Out:
# 'C:\\Users\\Danie\\git\\hub\\2021-09-13-python_live\\notebooks'

# %%
dat.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19080/2063868871.py in <module>
# ----> 1 dat.shape()
#
# TypeError: 'tuple' object is not callable

# %%
dat.shape
# Out:
# (1704, 6)

# %%
dat.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
dat.tail()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
dat.sample(10)
# Out:
#                  country continent  year  lifeExp        pop     gdpPercap
# 567              Germany    Europe  1967   70.800   76368453  14745.625610
# 574              Germany    Europe  2002   78.670   82350671  30035.801980
# 401       Czech Republic    Europe  1977   70.710   10161915  14800.160620
# 1250         Puerto Rico  Americas  1962   69.620    2448046   5108.344630
# 318              Comoros    Africa  1982   52.933     348643   1267.100083
# 103           Bangladesh      Asia  1987   52.819  103764241    751.979403
# 1656  West Bank and Gaza      Asia  1952   43.160    1030585   1515.592329
# 370        Cote d'Ivoire    Africa  2002   46.832   16252726   1648.800823
# 178               Brazil  Americas  2002   71.006  179914212   8131.212843
# 1603      United Kingdom    Europe  1987   75.007   56981620  21664.787670

# %%
print(dat)
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
dat.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
dat.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
dat.values
# Out:
# array([['Afghanistan', 'Asia', 1952, 28.801, 8425333, 779.4453145],
#        ['Afghanistan', 'Asia', 1957, 30.332, 9240934, 820.8530296],
#        ['Afghanistan', 'Asia', 1962, 31.997, 10267083, 853.10071],
#        ...,
#        ['Zimbabwe', 'Africa', 1997, 46.809, 11404948, 792.4499603],
#        ['Zimbabwe', 'Africa', 2002, 39.989, 11926563, 672.0386227],
#        ['Zimbabwe', 'Africa', 2007, 43.487, 12311143, 469.7092981]],
#       dtype=object)

# %%
dat["country"]
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
type(dat["country"])
# Out:
# pandas.core.series.Series

# %%
country = dat["country"]

# %%
country
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
dat[["country", "pop"]]
# Out:
#           country       pop
# 0     Afghanistan   8425333
# 1     Afghanistan   9240934
# 2     Afghanistan  10267083
# 3     Afghanistan  11537966
# 4     Afghanistan  13079460
# ...           ...       ...
# 1699     Zimbabwe   9216418
# 1700     Zimbabwe  10704340
# 1701     Zimbabwe  11404948
# 1702     Zimbabwe  11926563
# 1703     Zimbabwe  12311143
#
# [1704 rows x 2 columns]

# %%
dat.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
dat[["country"]]
# Out:
#           country
# 0     Afghanistan
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# ...           ...
# 1699     Zimbabwe
# 1700     Zimbabwe
# 1701     Zimbabwe
# 1702     Zimbabwe
# 1703     Zimbabwe
#
# [1704 rows x 1 columns]

# %%
type(dat[["country"]])
# Out:
# pandas.core.frame.DataFrame

# %%
dat.loc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
dat.loc[800]
# Out:
# country            Japan
# continent           Asia
# year                1992
# lifeExp            79.36
# pop            124329269
# gdpPercap    26824.89511
# Name: 800, dtype: object

# %%
dat
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
dat.loc[[0, 800]]
# Out:
#          country continent  year  lifeExp        pop     gdpPercap
# 0    Afghanistan      Asia  1952   28.801    8425333    779.445314
# 800        Japan      Asia  1992   79.360  124329269  26824.895110

# %%
dat.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\miniforge3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19080/823230228.py in <module>
# ----> 1 dat.loc[-1]
#
# ~\miniforge3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ...

# %%
dat.iloc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
dat.iloc[[0, 800]]
# Out:
#          country continent  year  lifeExp        pop     gdpPercap
# 0    Afghanistan      Asia  1952   28.801    8425333    779.445314
# 800        Japan      Asia  1992   79.360  124329269  26824.895110

# %%
dat.iloc[-1]
# Out:
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
dat.loc[:, :]
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
dat.loc[:, ["year", "pop"]]
# Out:
#       year       pop
# 0     1952   8425333
# 1     1957   9240934
# 2     1962  10267083
# 3     1967  11537966
# 4     1972  13079460
# ...    ...       ...
# 1699  1987   9216418
# 1700  1992  10704340
# 1701  1997  11404948
# 1702  2002  11926563
# 1703  2007  12311143
#
# [1704 rows x 2 columns]

# %%
dat.loc[[0, 100, 1000], ["year", "pop"]]
# Out:
#       year       pop
# 0     1952   8425333
# 100   1972  70759295
# 1000  1972   1320500

# %%
dat.iloc[[0, 100, 1000], [1, 3]]
# Out:
#      continent  lifeExp
# 0         Asia   28.801
# 100       Asia   45.252
# 1000      Asia   53.754

# %%
dat.loc[dat["country"] == "Zimbabwe", :]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1692  Zimbabwe    Africa  1952   48.451   3080907  406.884115
# 1693  Zimbabwe    Africa  1957   50.469   3646340  518.764268
# 1694  Zimbabwe    Africa  1962   52.358   4277736  527.272182
# 1695  Zimbabwe    Africa  1967   53.995   4995432  569.795071
# 1696  Zimbabwe    Africa  1972   55.635   5861135  799.362176
# 1697  Zimbabwe    Africa  1977   57.674   6642107  685.587682
# 1698  Zimbabwe    Africa  1982   60.363   7636524  788.855041
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
dat.loc[(dat["country"] == "Zimbabwe") & (dat["year"] > 1990), :] # | for "or"
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
dat.groupby("year")["lifeExp"].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
import numpy as np

dat.groupby("year")["lifeExp"].agg(np.mean)
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
dat.groupby(["year", "continent"])[["lifeExp", "pop"]].agg([np.mean, np.std])
# Out:
#                   lifeExp                      pop
#                      mean        std          mean           std
# year continent
# 1952 Africa     39.135500   5.151581  4.570010e+06  6.317450e+06
#      Americas   53.279840   9.326082  1.380610e+07  3.234163e+07
#      Asia       46.314394   9.291751  4.228356e+07  1.132267e+08
#      Europe     64.408500   6.361088  1.393736e+07  1.724745e+07
#      Oceania    69.255000   0.190919  5.343003e+06  4.735083e+06
# 1957 Africa     41.266346   5.620123  5.093033e+06  7.076042e+06
#      Americas   55.960280   9.033192  1.547816e+07  3.553706e+07
#      Asia       49.318544   9.635429  4.735699e+07  1.280961e+08
#      Europe     66.703067   5.295805  1.459635e+07  1.783235e+07
#      Oceania    70.295000   0.049497  5.970988e+06  5.291395e+06
# 1962 Africa     43.319442   5.875364  5.702247e+06  7.957545e+06
#      Americas   58.398760   8.503544  1.733081e+07  3.887683e+07
# ...

# %%
(dat
 .groupby(["year", "continent"])
 [["lifeExp", "pop"]]
 .agg([np.mean, np.std])
)
# Out:
#                   lifeExp                      pop
#                      mean        std          mean           std
# year continent
# 1952 Africa     39.135500   5.151581  4.570010e+06  6.317450e+06
#      Americas   53.279840   9.326082  1.380610e+07  3.234163e+07
#      Asia       46.314394   9.291751  4.228356e+07  1.132267e+08
#      Europe     64.408500   6.361088  1.393736e+07  1.724745e+07
#      Oceania    69.255000   0.190919  5.343003e+06  4.735083e+06
# 1957 Africa     41.266346   5.620123  5.093033e+06  7.076042e+06
#      Americas   55.960280   9.033192  1.547816e+07  3.553706e+07
#      Asia       49.318544   9.635429  4.735699e+07  1.280961e+08
#      Europe     66.703067   5.295805  1.459635e+07  1.783235e+07
#      Oceania    70.295000   0.049497  5.970988e+06  5.291395e+06
# 1962 Africa     43.319442   5.875364  5.702247e+06  7.957545e+06
#      Americas   58.398760   8.503544  1.733081e+07  3.887683e+07
# ...

# %%
(dat
 .groupby(["year", "continent"])
 [["lifeExp", "pop"]]
 .agg([np.mean, np.std])
 .reset_index()
)
# Out:
#     year continent    lifeExp                      pop
#                          mean        std          mean           std
# 0   1952    Africa  39.135500   5.151581  4.570010e+06  6.317450e+06
# 1   1952  Americas  53.279840   9.326082  1.380610e+07  3.234163e+07
# 2   1952      Asia  46.314394   9.291751  4.228356e+07  1.132267e+08
# 3   1952    Europe  64.408500   6.361088  1.393736e+07  1.724745e+07
# 4   1952   Oceania  69.255000   0.190919  5.343003e+06  4.735083e+06
# 5   1957    Africa  41.266346   5.620123  5.093033e+06  7.076042e+06
# 6   1957  Americas  55.960280   9.033192  1.547816e+07  3.553706e+07
# 7   1957      Asia  49.318544   9.635429  4.735699e+07  1.280961e+08
# 8   1957    Europe  66.703067   5.295805  1.459635e+07  1.783235e+07
# 9   1957   Oceania  70.295000   0.049497  5.970988e+06  5.291395e+06
# 10  1962    Africa  43.319442   5.875364  5.702247e+06  7.957545e+06
# 11  1962  Americas  58.398760   8.503544  1.733081e+07  3.887683e+07
# ...

# %%
grouped = (dat
 .groupby(["year"])
 [["lifeExp", "pop"]]
 .agg(np.mean)
 .reset_index()
)

# %%
grouped
# Out:
#     year    lifeExp           pop
# 0   1952  49.057620  1.695040e+07
# 1   1957  51.507401  1.876341e+07
# 2   1962  53.609249  2.042101e+07
# 3   1967  55.678290  2.265830e+07
# 4   1972  57.647386  2.518998e+07
# 5   1977  59.570157  2.767638e+07
# 6   1982  61.533197  3.020730e+07
# 7   1987  63.212613  3.303857e+07
# 8   1992  64.160338  3.599092e+07
# 9   1997  65.014676  3.883947e+07
# 10  2002  65.694923  4.145759e+07
# 11  2007  67.007423  4.402122e+07

# %%
type(grouped)
# Out:
# pandas.core.frame.DataFrame

# %%
grouped.loc[grouped["lifeExp"] > 65, :]
# Out:
#     year    lifeExp           pop
# 9   1997  65.014676  3.883947e+07
# 10  2002  65.694923  4.145759e+07
# 11  2007  67.007423  4.402122e+07

# %%
grouped.plot("lifeExp")
# Out:
# <AxesSubplot:xlabel='lifeExp'>

# %%
grouped_multi = (dat
 .groupby(["year", "continent"])
 [["lifeExp", "pop"]]
 .agg([np.mean, np.std])
)

# %%
grouped_multi.stack().reset_index()
# Out:
#      year continent level_2    lifeExp           pop
# 0    1952    Africa    mean  39.135500  4.570010e+06
# 1    1952    Africa     std   5.151581  6.317450e+06
# 2    1952  Americas    mean  53.279840  1.380610e+07
# 3    1952  Americas     std   9.326082  3.234163e+07
# 4    1952      Asia    mean  46.314394  4.228356e+07
# ..    ...       ...     ...        ...           ...
# 115  2007      Asia     std   7.963724  2.896734e+08
# 116  2007    Europe    mean  77.648600  1.953662e+07
# 117  2007    Europe     std   2.979813  2.362474e+07
# 118  2007   Oceania    mean  80.719500  1.227497e+07
# 119  2007   Oceania     std   0.729027  1.153885e+07
#
# [120 rows x 5 columns]
